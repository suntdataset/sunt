# %%
import pandas as pd

# %%
df = pd.read_csv('routes.txt')

# %%
df.head()
# Out:
#    route_id route_short_name                              route_long_name  \
# 0         9             B001  B001- (IDA)  EST. RODOVIÁRIA x EST. PITUBA
# 1        10             B001                                            -
# 2        13             B002                                        (IDA)
# 3        14             B002                                      (VOLTA)
#
#    route_type
# 0           3
# 1           3
# 2           3
# 3           3

# %%
stops = pd.read_csv('stops.txt')
stops.head()
# Out:
#    stop_id                         stop_name   stop_lat   stop_lon
# 0        2              PRACA BELO HORIZONTE -13.004483 -38.458888
# 1       10          ESTACAO ITAIGARA (VOLTA) -12.996823 -38.465057
# 2       23             PONTO COLEGIO MILITAR -12.994241 -38.454725
# 3       26                   PONTO RUA BAHIA -13.003300 -38.455461
# 4       11  ESTACAO PARQUE DA CIDADE (VOLTA) -12.996115 -38.471142

# %%
stops
# Out:
#     stop_id                         stop_name   stop_lat   stop_lon
# 0         2              PRACA BELO HORIZONTE -13.004483 -38.458888
# 1        10          ESTACAO ITAIGARA (VOLTA) -12.996823 -38.465057
# 2        23             PONTO COLEGIO MILITAR -12.994241 -38.454725
# 3        26                   PONTO RUA BAHIA -13.003300 -38.455461
# 4        11  ESTACAO PARQUE DA CIDADE (VOLTA) -12.996115 -38.471142
# 5        21               CAMINHO DAS ARVORES -12.986442 -38.457540
# 6        20                      MILTON BRITO -12.980759 -38.458537
# 7        18        ESTACAO BRT PITUBA (VOLTA) -13.000061 -38.459617
# 8         3            ESTACAO RODOVIARIA SUL -12.978994 -38.463843
# 9        25                  PONTO RIO BRANCO -12.999736 -38.454829
# 10       12             ESTACAO HIPER (VOLTA) -12.984846 -38.466875
# 11        4               ESTACAO HIPER (IDA) -12.984652 -38.466868
# 12       22                    PONTO PAULO VI -12.990615 -38.454733
# ...

# %%
stops.parent_station.nunique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_318375/4049703208.py in <module>
# ----> 1 stops.parent_station.nunique()
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'parent_station'
