# %%
import torch
import torch.nn as nn
import torch.optim as optim
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("semana-01-05-abril.csv")

# %%
# Converta a coluna 'date' para o formato datetime, se necessário
df['date'] = pd.to_datetime(df['date'])

# Configurações do gráfico
plt.figure(figsize=(10, 6))

# Agrupamento e plotagem
for date, group in df.groupby('date'):
    plt.plot(group['faixa'], group['tempo_total'], marker='o', label=date.date())

# Personalização do gráfico
plt.xlabel("Hour Interval")
plt.ylabel("Total Time")
plt.legend(title="Date")
plt.grid(True)
plt.show()

# %%
from sklearn.ensemble import IsolationForest

model = IsolationForest(contamination=0.05, random_state=42)
df['outlier'] = model.fit_predict(df[['tempo_total']])
df['outlier'] = df['outlier'] == -1

# %%
plt.figure(figsize=(12, 6))
plt.plot(df['datetime'], df['tempo_total'], label="Total Time")
plt.scatter(df['datetime'][df['outlier']], df['tempo_total'][df['outlier']], color='red', label="Outliers")
plt.title("")
plt.xlabel("Date / Hour Interval")
plt.ylabel("Total Time")
plt.legend()
plt.grid()
plt.show()
